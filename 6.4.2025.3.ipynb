# %%
import numpy as np
from IPython.display import display
import pandas as pd
import matplotlib.pyplot as plt

# %%
#שיעורי בית מצגת 23 שקף 23
fig = plt.figure() 
fig, ax = plt.subplots(nrows = 2, ncols = 1) 
x1 = np.arange(0, 5, 0.1)
x2 = np.arange(0, 5, 0.1)
y_sin = np.sin(x1)
y_cos = np.cos(x2)

ax[0].plot(x, y_sin, label='sin(x)', color='blue')
ax[0].set_title('Sine Function')
ax[0].set_xlabel('X Values')
ax[0].set_ylabel('sin(x)')
ax[0].legend(loc = (1.1, 0.85))
ax[0].grid(True)

ax[1].plot(x, y_cos, label='cos(x)', color='pink')
ax[1].set_title('Cosine Function')
ax[1].set_xlabel('X Values')
ax[1].set_ylabel('cos(x)')
ax[1].legend(loc = (1.1, 0.85))
ax[1].grid(True)

plt.tight_layout()
plt.show()
